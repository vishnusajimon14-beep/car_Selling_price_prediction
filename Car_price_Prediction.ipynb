# %%
## importing all essential libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Car details v3.csv")         #loading the dataset

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
df.shape
# Out:
# (8128, 13)

# %%
# checking the missing values
row_with_nul=df[df.isnull().any(axis=1)]
print(row_with_nul)
# Out:
#                                       name  year  selling_price  km_driven  \
# 13                    Maruti Swift 1.3 VXi  2007         200000      80000
# 31                      Fiat Palio 1.2 ELX  2003          70000      50000
# 78                         Tata Indica DLS  2003          50000      70000
# 87             Maruti Swift VDI BSIV W ABS  2015         475000      78000
# 119                  Maruti Swift VDI BSIV  2010         300000     120000
# ...                                    ...   ...            ...        ...
# 7846                Toyota Qualis Fleet A3  2000         200000     100000
# 7996             Hyundai Santro LS zipPlus  2000         140000      50000
# 8009  Hyundai Santro Xing XS eRLX Euro III  2006         145000      80000
# 8068             Ford Figo Aspire Facelift  2017         580000     165000
# 8103                  Maruti Swift 1.3 VXi  2006         130000     100000
#
# ...

# %%
df['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %%
df['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
df['transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner', 'Test Drive Car'], dtype=object)

# %%
df['name'].unique()
# Out:
# array(['Maruti Swift Dzire VDI', 'Skoda Rapid 1.5 TDI Ambition',
#        'Honda City 2017-2020 EXi', ..., 'Tata Nexon 1.5 Revotorq XT',
#        'Ford Freestyle Titanium Plus Diesel BSIV',
#        'Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV'], dtype=object)

# %%
print(df[df['name']=='Maruti Swift 1.3 VXi']['engine'])
# Out:
# 13      NaN
# 228     NaN
# 306     NaN
# 743     NaN
# 1331    NaN
# 1785    NaN
# 4731    NaN
# 5742    NaN
# 5817    NaN
# 6404    NaN
# 7179    NaN
# 7433    NaN
# 7582    NaN
# 8103    NaN
# Name: engine, dtype: object

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8123    False
# 8124    False
# 8125    False
# 8126     True
# 8127     True
# Length: 8128, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(1202)

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner     mileage  \
# ...

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          208
# engine           208
# max_power        205
# torque           209
# seats            208
# dtype: int64

# %%
# df=df.dropna()

# %%
# df.tail(10)

# %%
df.shape
# Out:
# (6926, 13)

# %%
# df['mileage']=df['mileage'].str.extract('(\d+\.?\d*)')[0].astype(float)

# %%
df.loc[:, 'mileage'] =(df['mileage'].str.extract(r'(\d+\.?\d*)')[0].astype(float))

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner mileage   engine   max_power  \
# 0  Individual       Manual   First Owner    23.4  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner   21.14  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner    17.7  1497 CC      78 bhp
# 3  Individual       Manual   First Owner    23.0  1396 CC      90 bhp
# 4  Individual       Manual   First Owner    16.1  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# ...

# %%
df.loc[:, 'engine'] =(df['engine'].str.extract(r'(\d+)')[0].astype(float))

# %%
df.loc[:, 'max_power'] =(df['max_power'].str.extract(r'(\d+\.?\d*)')[0].astype(float))

# %%
import re
def convert_torque(value):
    if pd.isna(value):
        return np.nan

    value = str(value).lower()

    # If Nm exists, extract Nm value directly
    if 'nm' in value:
        match = re.search(r'(\d+\.?\d*)\s*nm', value)
        if match:
            return float(match.group(1))

    # Else if kgm exists, convert to Nm
    elif 'kgm' in value:
        match = re.search(r'(\d+\.?\d*)\s*kgm', value)
        if match:
            return float(match.group(1)) * 9.80665

    return np.nan

df['torque'] = df['torque'].apply(convert_torque)

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner mileage  engine  \
# ...

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          208
# engine           208
# max_power        206
# torque           596
# seats            208
# dtype: int64

# %%
cols = ['mileage', 'engine', 'seats', 'torque', 'max_power']

for col in cols:
    df[col] = df.groupby(['name', 'fuel'])[col].transform(
        lambda x: x.fillna(x.median())
    )
# Out:
# Streaming output truncated to the last 5000 lines.
# /tmp/ipykernel_420/2655100089.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   lambda x: x.fillna(x.median())
# /tmp/ipykernel_420/2655100089.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   lambda x: x.fillna(x.median())
# ...

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          152
# engine           152
# max_power        153
# torque           527
# seats            152
# dtype: int64

# %%
df.dropna(inplace=True)
print(df.isnull().sum())
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# dtype: int64

# %%
df.shape
# Out:
# (6399, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6399 entries, 0 to 8125
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6399 non-null   object
#  1   year           6399 non-null   int64
#  2   selling_price  6399 non-null   int64
#  3   km_driven      6399 non-null   int64
#  4   fuel           6399 non-null   object
#  5   seller_type    6399 non-null   object
#  6   transmission   6399 non-null   object
#  7   owner          6399 non-null   object
#  8   mileage        6399 non-null   float64
#  9   engine         6399 non-null   float64
#  10  max_power      6399 non-null   float64
#  11  torque         6399 non-null   float64
#  12  seats          6399 non-null   float64
# dtypes: float64(5), int64(3), object(5)
# memory usage: 699.9+ KB

# %%
df.describe()
# Out:
#               year  selling_price     km_driven      mileage       engine  \
# count  6399.000000   6.399000e+03  6.399000e+03  6399.000000  6399.000000
# mean   2013.910142   5.382689e+05  7.087870e+04    19.735701  1411.300985
# std       3.717420   5.289529e+05  5.735075e+04     3.995887   485.740698
# min    1994.000000   2.999900e+04  1.000000e+00     0.000000   624.000000
# 25%    2012.000000   2.650000e+05  3.500000e+04    17.000000  1196.000000
# 50%    2014.000000   4.300000e+05  6.400000e+04    19.700000  1248.000000
# 75%    2017.000000   6.500000e+05  9.800000e+04    22.740000  1498.000000
# max    2020.000000   1.000000e+07  2.360457e+06    42.000000  3604.000000
#
#          max_power       torque        seats
# count  6399.000000  6399.000000  6399.000000
# mean     87.443767   171.178750     5.417722
# std      31.962183    85.308038     0.958047
# min       0.000000    47.071920     2.000000
# 25%      67.100000   110.000000     5.000000
# ...

# %%
obj_col=['mileage','engine','max_power','torque']
for col in obj_col:
    df[col]=df[col].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6399 entries, 0 to 8125
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6399 non-null   object
#  1   year           6399 non-null   int64
#  2   selling_price  6399 non-null   int64
#  3   km_driven      6399 non-null   int64
#  4   fuel           6399 non-null   object
#  5   seller_type    6399 non-null   object
#  6   transmission   6399 non-null   object
#  7   owner          6399 non-null   object
#  8   mileage        6399 non-null   int64
#  9   engine         6399 non-null   int64
#  10  max_power      6399 non-null   int64
#  11  torque         6399 non-null   int64
#  12  seats          6399 non-null   float64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 699.9+ KB

# %%
df['age']=2026-df['year']

# %%
df['seats'].unique()
# Out:
# array([ 5.,  4.,  7.,  8.,  6.,  9., 10., 14.,  2.])

# %%
print(df[df['seats']==9])
# Out:
#                                            name  year  selling_price  \
# 276                         Mahindra Scorpio LX  2011         404000
# 637    Mahindra Bolero 2011-2019 DI - AC BS III  2017         700000
# 711     Chevrolet Tavera Neo 3 LT 9 Seats BSIII  2014         600000
# 724           Mahindra Bolero 2011-2019 Plus AC  2016         550000
# 727   Mahindra Bolero 2011-2019 Plus - AC BSIII  2011         320000
# ...                                         ...   ...            ...
# 7117    Chevrolet Tavera Neo 3 LT 9 Seats BSIII  2016         900000
# 7130   Mahindra Bolero 2011-2019 DI - AC BS III  2016         560000
# 7131   Mahindra Bolero 2011-2019 DI - AC BS III  2016         600000
# 7150         Chevrolet Tavera Neo 3 9 Str BSIII  2015         425000
# 7462                        Mahindra Scorpio LX  2011         550000
#
#       km_driven    fuel seller_type transmission         owner  mileage  \
# ...

# %%
df['brand']=df['name'].str.split().str[0]
df['seats']=df['seats'].astype(int)

# %%
sns.histplot(x='seats',y='selling_price',kde=True,data=df)
# Out:
# <Axes: xlabel='seats', ylabel='selling_price'>

# %%
sns.boxplot(x='seats',y='selling_price',data=df)
# Out:
# <Axes: xlabel='seats', ylabel='selling_price'>

# %%
# !pip install statannotations
from statannotations.Annotator import Annotator

plt.figure(figsize=(12,6))

ax = sns.boxplot(
    x='seats',
    y='selling_price',
    data=df
)

# Compare pairs
pairs = [
    (5,7),
    (5,8),
    (4,5),
    (5,10),
    (5,9)
]

annotator = Annotator(
    ax,
    pairs,
    data=df,
    x='seats',
    y='selling_price'
)

annotator.configure(
    test='Mann-Whitney',
    text_format='star',
    loc='inside'
)

annotator.apply_and_annotate()

plt.title('Selling Price vs Seats')
plt.show()
# Out:
# ...
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# 4 vs. 5: Mann-Whitney-Wilcoxon test two-sided, P_val:5.891e-54 U_stat=5.717e+04
# 5 vs. 7: Mann-Whitney-Wilcoxon test two-sided, P_val:7.331e-121 U_stat=1.209e+06
# 5 vs. 8: Mann-Whitney-Wilcoxon test two-sided, P_val:7.159e-03 U_stat=4.130e+05
# 5 vs. 9: Mann-Whitney-Wilcoxon test two-sided, P_val:1.242e-04 U_stat=1.289e+05
# 5 vs. 10: Mann-Whitney-Wilcoxon test two-sided, P_val:3.298e-01 U_stat=1.609e+04

# %% [markdown]
# # One way anaova

# %%
group=[
    group['selling_price'].values
    for name,group in df.groupby('seats')
]

# %%
from scipy.stats import f_oneway
f_stst,p_value=f_oneway(*group)

# %%
print(f_stst)
print(p_value)
# Out:
# 38.319733056285614
# 5.080201586387183e-60

# %% [markdown]
# One-way ANOVA further confirmed that selling prices vary significantly across seating-capacity categories (p < 0.05), indicating that seating capacity has a statistically significant influence on car selling price.

# %% [markdown]
# # JT test

# %%
pip install scikit-posthocs

# %%
import scikit_posthocs as sp
result=sp.test_osrt(df,val_col='selling_price',group_col='seats')

# %%
print(result)
# Out:
# (np.float64(2.8825830611367564e-12), np.float64(24.29140451847576), 6390)

# %%
numerical_cols=['year','selling_price','km_driven','mileage','engine','max_power','seats','torque']

# %% [markdown]
# Identified skewness

# %%
for col in numerical_cols:
  print(f"skweness for {col} :{df[col].skew()}")
# Out:
# skweness for year :-1.0703820018059698
# skweness for selling_price :5.592851458114679
# skweness for km_driven :13.26710903204227
# skweness for mileage :-0.1958757159453441
# skweness for engine :1.2835601146445974
# skweness for max_power :1.716736677845575
# skweness for seats :1.9055619149356209
# skweness for torque :1.3279496725046784

# %%
# jt test,anova

# %%
df['brand'].unique()
# Out:
# array(['Maruti', 'Skoda', 'Hyundai', 'Toyota', 'Ford', 'Renault',
#        'Mahindra', 'Honda', 'Tata', 'Chevrolet', 'Datsun', 'Jeep',
#        'Mercedes-Benz', 'Mitsubishi', 'Audi', 'Volkswagen', 'BMW',
#        'Nissan', 'Lexus', 'Jaguar', 'Land', 'MG', 'Volvo', 'Daewoo',
#        'Kia', 'Fiat', 'Force', 'Ambassador', 'Ashok', 'Isuzu', 'Opel'],
#       dtype=object)

# %%
## analysis

# %%
numerical_cols=['year','selling_price','km_driven','mileage','engine','max_power','seats','torque']
plt.figure(figsize=(15,10))

for i, col in enumerate(numerical_cols, 1):
    plt.subplot(3, 3, i)
    sns.histplot(df[col], kde=True)
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(np.log1p(df['selling_price']), kde=True)

plt.title('Log Transformed Selling Price')

plt.show()

# %%
# skweness value,0.05 less,yejohnoson for fixing skewness

# %% [markdown]
# ### Target Transformation Lookup
#
#
# | Log Value | Approx Selling Price | Note / Comment |
# | :--- | :--- | :--- |
# | **11** | ~60,000 | Baseline for low-budget / older hatchbacks. |
# | **12** | ~1.6 lakh | Typical price floor for mid-range used sedans. |
# | **13** | ~4.4 lakh | Average range for premium hatchbacks or compact SUVs. |
# | **14** | ~12 lakh | Entry-level luxury cars or brand-new mid-SUVs. |
# | **15** | ~32 lakh | Luxury segment cars (BMW 3 Series, Audi A4, etc.). |
# | **16** | ~88 lakh | Supercars, premium imports, or high-end luxury SUVs. |

# %% [markdown]
# The original selling price distribution was highly positively skewed due to presence of luxury vehicles and extreme outliers. Applying logarithmic transformation significantly reduced skewness and produced a near-normal distribution, making the data more suitable for regression modeling.
#
# Most values lie between 12.5 and 13.5 that is 3-7 lakh

# %%
plt.figure(figsize=(5,5))

sns.histplot(np.log1p(df['km_driven']), kde=True)
plt.title('Log Transformed km_driven')
plt.show()

# %% [markdown]
# The original km_driven feature exhibited strong positive skewness due to presence of high-mileage vehicles. Logarithmic transformation reduced skewness and produced a more compact distribution. Most vehicles in the dataset have driven between approximately 40,000 km and 100,000 km.

# %%
cat_cols=['fuel','seller_type','transmission','owner','brand']
plt.figure(figsize=(20,10))
for i,col in enumerate(cat_cols,1):
    plt.subplot(3,3,i)
    sns.countplot(x=col,data=df)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(50,20))
for i,col in enumerate(numerical_cols,1):
    plt.subplot(3,3,i)
    sns.boxplot(df[col])
plt.tight_layout()
plt.show()

# %%
df.sort_values('km_driven',ascending=False).head(10)
# Out:
#                                                name  year  selling_price  \
# 3486                           Hyundai i20 Asta 1.2  2007         550000
# 1810                         Mahindra XUV500 W6 2WD  2012         500000
# 3508                       Maruti Wagon R LXI Minor  2010         194000
# 6673  Toyota Innova 2.5 EV Diesel PS 7 Seater BSIII  2011         350000
# 3641                       Maruti Wagon R VXI BS IV  2011         229999
# 5106                          Mahindra Scorpio M2DI  2011         400000
# 5189         Toyota Innova 2.5 VX (Diesel) 7 Seater  2013         750000
# 2272                            Mahindra Bolero SLE  2010         260000
# 2006    Toyota Innova 2.5 G (Diesel) 7 Seater BS IV  2011         650000
# 5871                            Mahindra Scorpio LX  2012         450000
#
#       km_driven    fuel seller_type transmission         owner  mileage  \
# 3486    2360457  Petrol  Individual       Manual  Second Owner       18
# ...

# %%
df.sort_values('selling_price',ascending=False).head(10)
# Out:
#                                   name  year  selling_price  km_driven  \
# 170      Volvo XC90 T8 Excellence BSIV  2017       10000000      30000
# 2938             BMW X7 xDrive 30d DPE  2020        7200000       5000
# 4952            Audi A6 35 TFSI Matrix  2019        6523000      23600
# 4950            Audi A6 35 TFSI Matrix  2019        6223000       7800
# 1071  BMW 6 Series GT 630d Luxury Line  2018        6000000      28156
# 4766  BMW 6 Series GT 630d Luxury Line  2018        6000000      27000
# 136    Mercedes-Benz S-Class S 350 CDI  2017        6000000      37000
# 4951            Audi A6 35 TFSI Matrix  2019        5923000      11500
# 148    Mercedes-Benz S-Class S 350 CDI  2017        5850000      47000
# 6258  BMW 6 Series GT 630d Luxury Line  2018        5830000      30000
#
#         fuel seller_type transmission           owner  mileage  engine  \
# 170   Petrol  Individual    Automatic     First Owner       42    1969
# ...

# %%
df.sort_values('mileage',ascending=True)
# Out:
#                                   name  year  selling_price  km_driven  \
# 6629   Mahindra Bolero Pik-Up CBC 1.7T  2019         722000      80000
# 5276            Hyundai Santro Xing GL  2008         175000      40000
# 2725      Hyundai Santro Xing (Non-AC)  2013         184000      15000
# 6824            Hyundai Santro Xing GL  2011         150000      40000
# 1649            Hyundai Santro Xing GL  2008         105000     128000
# ...                                ...   ...            ...        ...
# 5789           Maruti Alto K10 LXI CNG  2019         430000      20000
# 3908           Maruti Alto 800 CNG LXI  2017         260000      67000
# 35    Maruti Alto 800 CNG LXI Optional  2019         330000      10000
# 5815           Maruti Alto 800 LXI CNG  2020         370000      16000
# 170      Volvo XC90 T8 Excellence BSIV  2017       10000000      30000
#
#         fuel seller_type transmission                 owner  mileage  engine  \
# ...

# %%
df.sort_values('max_power',ascending=True)
# Out:
#                                            name  year  selling_price  \
# 575                         Maruti Alto K10 LXI  2011         204999
# 1442            Maruti Swift Dzire VDI Optional  2017         589000
# 2549             Tata Indica Vista Quadrajet LS  2012         240000
# 6007  Maruti Omni LPG CARGO BSIII W IMMOBILISER  2007          54000
# 3466  Maruti Omni LPG CARGO BSIII W IMMOBILISER  2010         120000
# ...                                         ...   ...            ...
# 2826       Jaguar XF 3.0 Litre S Premium Luxury  2014        2000000
# 5962          Mercedes-Benz E-Class E350 Petrol  2009        1000000
# 134             Jeep Wrangler 2016-2019 3.6 4X4  2017        4100000
# 148             Mercedes-Benz S-Class S 350 CDI  2017        5850000
# 170               Volvo XC90 T8 Excellence BSIV  2017       10000000
#
#       km_driven    fuel seller_type transmission         owner  mileage  \
# ...

# %%
df=df[df['km_driven']<=500000].copy()

# %%
df['mileage']=df['mileage'].replace(0,np.nan)
df['mileage']=df.groupby(['name','transmission','fuel'])['mileage'].transform(lambda x:x.fillna(x.median()))

# %%
df['max_power']=df['max_power'].replace(0,np.nan)
df['max_power']=df.groupby(['name','fuel','transmission'])['max_power'].transform(lambda x:x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# name              0
# year              0
# selling_price     0
# km_driven         0
# fuel              0
# seller_type       0
# transmission      0
# owner             0
# mileage          13
# engine            0
# max_power         0
# torque            0
# seats             0
# age               0
# brand             0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#               year  selling_price      km_driven      mileage       engine  \
# count  6383.000000   6.383000e+03    6383.000000  6383.000000  6383.000000
# mean   2013.914460   5.380925e+05   70240.631365    19.336206  1411.140060
# std       3.716305   5.281127e+05   45961.087435     3.921122   485.552442
# min    1994.000000   2.999900e+04       1.000000     9.000000   624.000000
# 25%    2012.000000   2.670000e+05   35000.000000    17.000000  1196.000000
# 50%    2014.000000   4.300000e+05   64000.000000    19.000000  1248.000000
# 75%    2017.000000   6.500000e+05   98000.000000    22.000000  1498.000000
# max    2020.000000   1.000000e+07  500000.000000    42.000000  3604.000000
#
#          max_power       torque        seats          age
# count  6383.000000  6383.000000  6383.000000  6383.000000
# mean     87.165596   171.073476     5.419395    12.085540
# std      31.865802    85.258405     0.956945     3.716305
# min      32.000000    47.000000     4.000000     6.000000
# ...

# %% [markdown]
# ## bivarient analysis

# %%
#### numerical vs numerical

# %%
plt.figure(figsize=(30,10))
for i,col in enumerate(numerical_cols,1):
    plt.subplot(3,3,i)
    sns.scatterplot(y=df['selling_price'],x=df[col],data=df)
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# The scatter plot analysis shows that newer vehicles, higher engine capacity, max power, and torque generally lead to higher selling prices, while higher kilometers driven reduce vehicle value. Performance-related features strongly influence car prices, whereas mileage alone has a weaker impact on resale value

# %%
plt.figure(figsize=(30,10))
for i ,col in enumerate(cat_cols,1):
    plt.subplot(3,3,i)
    sns.boxplot(y=df['selling_price'],x=df[col],data=df)
plt.tight_layout()
plt.show()

# %%
## heatmap for bivarient analysis

# %%
sns.heatmap(df[numerical_cols].corr(),annot=True,fmt=".2f",cmap='coolwarm')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(50,30))
for i,col in enumerate(cat_cols,1):
    plt.subplot(3,3,i)
    sns.violinplot(x=col,y='selling_price',data=df)
plt.tight_layout()
plt.show()

# %% [markdown]
# The violin plot analysis shows that luxury brands have a wider price distribution with higher variance, while economy brands are concentrated in lower price ranges. Automatic and diesel vehicles also tend to occupy higher-priced segments compared to manual and petrol vehicles.

# %%
## using of pairplot

# %%
sns.pairplot(df,vars=None,hue='fuel',corner=True,plot_kws={'alpha': 0.3, 's': 15},diag_kind='kde')

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.boxplot(ax=axes[0],
    x='fuel', y='selling_price',
    hue='transmission', data=df)
axes[0].set_title('Price: fuel × transmission')
axes[0].tick_params(axis='x', rotation=20)

sns.boxplot(ax=axes[1],
    x='owner', y='selling_price',
    hue='fuel', data=df)
axes[1].set_title('Price: owner × fuel')
axes[1].tick_params(axis='x', rotation=30)

plt.tight_layout()
plt.show()

# %% [markdown]
# The boxplots reveal that transmission type, fuel category, and ownership history significantly influence vehicle resale price. Automatic diesel vehicles dominate the premium price segment, while LPG and CNG vehicles remain concentrated in lower-priced categories. First-owner vehicles maintain substantially higher resale values, whereas increasing ownership count corresponds to decreasing vehicle prices. Diesel vehicles consistently demonstrate stronger resale performance across ownership classes.

# %%
# Only top 10 by count (most data = most reliable medians)
top_brands = df['brand'].value_counts().head(10).index
brand_df = df[df['brand'].isin(top_brands)]

pivot = brand_df.groupby(['brand', 'fuel'])['selling_price']\
                .median().unstack()

plt.figure(figsize=(10, 6))
sns.heatmap(pivot / 1e5, annot=True, fmt='.1f',
            cmap='YlOrRd')
plt.title('Median price (lakhs): top 10 brands × fuel')
plt.show()

# %% [markdown]
# The heatmap reveals strong brand-wise and fuel-wise pricing patterns in the used car market. Diesel variants consistently achieve higher median resale prices across most brands, while CNG and LPG vehicles remain concentrated in lower-priced economy segments. Toyota and Honda diesel models dominate the premium resale category, indicating strong market demand and perceived reliabilit

# %% [markdown]
# Encoding

# %%
df['transmission']=df['transmission'].map({'Manual':0,'Automatic':1})
print(df['transmission'].value_counts())
# Out:
# transmission
# 0    5827
# 1     556
# Name: count, dtype: int64

# %%
df['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner', 'Test Drive Car'], dtype=object)

# %%
owner_map={
    'First Owner' : 1,
    'Second Owner' : 2,
    'Third Owner' : 3,
    'Fourth & Above Owner' :4,
    'Test Drive Car' :5
}
df['owner']=df['owner'].map(owner_map)
print(df['owner'].value_counts())
# Out:
# owner
# 1    4092
# 2    1736
# 3     417
# 4     133
# 5       5
# Name: count, dtype: int64

# %%
fuel_dummies = pd.get_dummies(df['fuel'], prefix='fuel',dtype=int, drop_first=True)
df = pd.concat([df, fuel_dummies], axis=1)
df.drop('fuel', axis=1, inplace=True)
print(df.filter(like='fuel_').head())
# Out:
#    fuel_Diesel  fuel_LPG  fuel_Petrol
# 0            1         0            0
# 1            1         0            0
# 3            1         0            0
# 5            0         0            1
# 7            0         0            1

# %%
seller_dummies = pd.get_dummies(df['seller_type'], prefix='seller', drop_first=True,dtype=int)
df = pd.concat([df, seller_dummies], axis=1)
df.drop('seller_type', axis=1, inplace=True)
print(df.filter(like='seller_').head())
# Out:
#    seller_Individual  seller_Trustmark Dealer
# 0                  1                        0
# 1                  1                        0
# 3                  1                        0
# 5                  1                        0
# 7                  1                        0

# %%
df.head()
# Out:
#                             name  year  selling_price  km_driven  \
# 0         Maruti Swift Dzire VDI  2014         450000     145500
# 1   Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 3      Hyundai i20 Sportz Diesel  2010         225000     127000
# 5  Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 7             Maruti 800 DX BSII  2001          45000       5000
#
#    transmission  owner  mileage  engine  max_power  torque  seats  age  \
# 0             0      1     23.0    1248       74.0     190      5   12
# 1             0      2     21.0    1498      103.0     250      5   12
# 3             0      1     23.0    1396       90.0     219      5   16
# 5             0      1     20.0    1197       81.0     113      5    9
# 7             0      2     16.0     796       37.0      59      4   25
#
#      brand  fuel_Diesel  fuel_LPG  fuel_Petrol  seller_Individual  \
# 0   Maruti            1         0            0                  1
# ...

# %%
df.isnull().sum()
# Out:
# name                       0
# year                       0
# selling_price              0
# km_driven                  0
# transmission               0
# owner                      0
# mileage                    0
# engine                     0
# max_power                  0
# torque                     0
# seats                      0
# age                        0
# brand                      0
# fuel_Diesel                0
# fuel_LPG                   0
# fuel_Petrol                0
# seller_Individual          0
# seller_Trustmark Dealer    0
# dtype: int64

# %%
brand_median=df.groupby('brand')['selling_price'].median().sort_values(ascending=False)
print(brand_median)
# Out:
# brand
# Lexus            5150000.0
# Volvo            3400000.0
# Land             3250000.0
# BMW              2725000.0
# Jaguar           2668000.0
# Audi             2100000.0
# Mercedes-Benz    2000000.0
# MG               1750000.0
# Jeep             1650000.0
# Kia              1575000.0
# Isuzu            1575000.0
# Mitsubishi       1170000.0
# Force             880000.0
# Toyota            819999.0
# Honda             600000.0
# Mahindra          585000.0
# Ford              500000.0
# Skoda             475000.0
# Hyundai           450000.0
# Volkswagen        418000.0
# Renault           395000.0
# Nissan            370000.0
# Maruti            353500.0
# Datsun            300000.0
# Ashok             300000.0
# Tata              300000.0
# Fiat              300000.0
# Chevrolet         220000.0
# Ambassador        110500.0
# Daewoo             86000.0
# Opel               68000.0
# Name: selling_price, dtype: float64

# %%
def brand_segment(brand):
    luxury = ['Lexus', 'Volvo', 'Jaguar', 'BMW',
              'Land', 'Audi', 'Mercedes-Benz']

    mid    = ['MG', 'Jeep', 'Kia', 'Isuzu', 'Force',
              'Toyota', 'Mitsubishi', 'Mahindra', 'Honda',
              'Ford', 'Volkswagen', 'Skoda']

    budget = ['Hyundai', 'Renault', 'Nissan', 'Maruti',
              'Datsun', 'Ashok', 'Fiat', 'Tata',
              'Chevrolet', 'Ambassador', 'Daewoo', 'Opel']

    if brand in luxury: return 2
    elif brand in mid:  return 1
    else:               return 0

df['brand_segment'] = df['brand'].apply(brand_segment)
df.drop('brand', axis=1, inplace=True)

print(df['brand_segment'].value_counts())
# Out:
# brand_segment
# 0    4381
# 1    1869
# 2     133
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                             name  year  selling_price  km_driven  \
# 0         Maruti Swift Dzire VDI  2014         450000     145500
# 1   Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 3      Hyundai i20 Sportz Diesel  2010         225000     127000
# 5  Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 7             Maruti 800 DX BSII  2001          45000       5000
#
#    transmission  owner  mileage  engine  max_power  torque  seats  age  \
# 0             0      1     23.0    1248       74.0     190      5   12
# 1             0      2     21.0    1498      103.0     250      5   12
# 3             0      1     23.0    1396       90.0     219      5   16
# 5             0      1     20.0    1197       81.0     113      5    9
# 7             0      2     16.0     796       37.0      59      4   25
#
#    fuel_Diesel  fuel_LPG  fuel_Petrol  seller_Individual  \
# 0            1         0            0                  1
# ...

# %%
df.drop(['name','year'],axis=1,inplace=True)
df
# Out:
#       selling_price  km_driven  transmission  owner  mileage  engine  \
# 0            450000     145500             0      1     23.0    1248
# 1            370000     120000             0      2     21.0    1498
# 3            225000     127000             0      1     23.0    1396
# 5            440000      45000             0      1     20.0    1197
# 7             45000       5000             0      2     16.0     796
# ...             ...        ...           ...    ...      ...     ...
# 8120         120000     191000             0      1     17.0    1086
# 8121         260000      50000             0      2     18.0     998
# 8122         475000      80000             0      2     22.0    1396
# 8123         320000     110000             0      1     18.0    1197
# 8125         382000     120000             0      1     19.0    1248
#
#       max_power  torque  seats  age  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# ...

# %%
df['log_selling_price']=np.log1p(df['selling_price'])
df.drop('selling_price',axis=1,inplace=True)

# %%
df
# Out:
#       km_driven  transmission  owner  mileage  engine  max_power  torque  \
# 0        145500             0      1     23.0    1248       74.0     190
# 1        120000             0      2     21.0    1498      103.0     250
# 3        127000             0      1     23.0    1396       90.0     219
# 5         45000             0      1     20.0    1197       81.0     113
# 7          5000             0      2     16.0     796       37.0      59
# ...         ...           ...    ...      ...     ...        ...     ...
# 8120     191000             0      1     17.0    1086       62.0      96
# 8121      50000             0      2     18.0     998       67.0      90
# 8122      80000             0      2     22.0    1396       88.0     219
# 8123     110000             0      1     18.0    1197       82.0     113
# 8125     120000             0      1     19.0    1248       73.0     190
#
#       seats  age  fuel_Diesel  fuel_LPG  fuel_Petrol  seller_Individual  \
# ...

# %%
df['log_km_Driven']=np.log1p(df['km_driven'])
df.drop('km_driven',axis=1,inplace=True)

# %%
df.dtypes
# Out:
# transmission                 int64
# owner                        int64
# mileage                    float64
# engine                       int64
# max_power                  float64
# torque                       int64
# seats                        int64
# age                          int64
# fuel_Diesel                  int64
# fuel_LPG                     int64
# fuel_Petrol                  int64
# seller_Individual            int64
# seller_Trustmark Dealer      int64
# brand_segment                int64
# log_selling_price          float64
# log_km_Driven              float64
# dtype: object

# %%
from sklearn.preprocessing import PowerTransformer
import joblib
pt_engine= PowerTransformer(method='yeo-johnson')
df['engine']=pt_engine.fit_transform(df[['engine']])
pt_max_power=PowerTransformer(method='yeo-johnson')
df['max_power']=pt_max_power.fit_transform(df[['max_power']])
joblib.dump(
    pt_max_power,
    'pt_max_power.pkl'
)
joblib.dump(
    pt_engine,
    'pt_engine.pkl'
)
# Out:
# ['pt_engine.pkl']

# %%
from sklearn.model_selection import train_test_split
x=df.drop(['log_selling_price','torque'],axis=1)
y=df['log_selling_price']
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
x.head()
# Out:
#    transmission  owner  mileage    engine  max_power  seats  age  fuel_Diesel  \
# 0             0      1     23.0 -0.142704  -0.287323      5   12            1
# 1             0      2     21.0  0.444647   0.698279      5   12            1
# 3             0      1     23.0  0.225592   0.305270      5   16            1
# 5             0      1     20.0 -0.286518  -0.010308      5    9            0
# 7             0      2     16.0 -1.900794  -2.606105      4   25            0
#
#    fuel_LPG  fuel_Petrol  seller_Individual  seller_Trustmark Dealer  \
# 0         0            0                  1                        0
# 1         0            0                  1                        0
# 3         0            0                  1                        0
# 5         0            1                  1                        0
# 7         0            1                  1                        0
#
#    brand_segment  log_km_Driven
# 0              0      11.887938
# ...

# %%
print(numerical_cols)
# Out:
# ['year', 'selling_price', 'km_driven', 'mileage', 'engine', 'max_power', 'seats', 'torque']

# %%
df.isnull().sum()
# Out:
# transmission               0
# owner                      0
# mileage                    0
# engine                     0
# max_power                  0
# torque                     0
# seats                      0
# age                        0
# fuel_Diesel                0
# fuel_LPG                   0
# fuel_Petrol                0
# seller_Individual          0
# seller_Trustmark Dealer    0
# brand_segment              0
# log_selling_price          0
# log_km_Driven              0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
num_cols=['mileage','engine','max_power','age','log_km_Driven']
x_train[num_cols]=sc.fit_transform(x_train[num_cols])
x_test[num_cols]=sc.transform(x_test[num_cols])

# %%
#model training

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error,root_mean_squared_error
from sklearn.model_selection import cross_validate
lr=LinearRegression()
cv=cross_validate(lr,x_train,y_train,cv=5,return_train_score=True,scoring={'r2':'r2',
        'mae':'neg_mean_absolute_error',
        'rmse':'neg_root_mean_squared_error'})
print("Train R2 Mean:",
      cv['train_r2'].mean())

print("Validation R2 Mean:",
      cv['test_r2'].mean())

print("Validation R2 Std:",
      cv['test_r2'].std())

print("Validation MAE:",
      -cv['test_mae'].mean())

print("Validation RMSE:",
      -cv['test_rmse'].mean())
# Out:
# Train R2 Mean: 0.8409315823817443
# Validation R2 Mean: 0.8393946194517701
# Validation R2 Std: 0.006892642176663342
# Validation MAE: 0.22608922359877073
# Validation RMSE: 0.2917550883724712

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_test_actual = np.expm1(y_test)
y_pred_actual = np.expm1(y_pred)

# %%
from sklearn.metrics import mean_absolute_error
print("MAE:",mean_absolute_error(y_test_actual, y_pred_actual))
print("MSE:",mean_squared_error(y_test_actual, y_pred_actual))
print("R2 Score:",r2_score(y_test, y_pred))
# Out:
# MAE: 124427.51835928702
# MSE: 73635197305.57047
# R2 Score: 0.8454281371643843

# %%
residual=y_test_actual-y_pred_actual

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(
    x=y_pred_actual,
    y=residual
)

plt.axhline(y=0, color='red', linestyle='--')

plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")

plt.show()

# %% [markdown]
# Residual analysis indicates that the model errors are
# approximately centered around zero, suggesting no major
# systematic bias.
#
# However, the residual spread increases for higher predicted
# prices, indicating heteroscedasticity. This suggests that
# Linear Regression struggles to model expensive vehicles
# consistently.
#
# The absence of strong nonlinear residual patterns suggests
# that logarithmic transformation improved linearity in the data.

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=100,max_depth=10)
cv_rf=cross_validate(rf,x_train,y_train,cv=5,scoring={
        'r2':'r2',
        'mae':'neg_mean_absolute_error',
        'rmse':'neg_root_mean_squared_error'
    },
    return_train_score=True,
    n_jobs=-1
)
print("Train R2 Mean:",
      cv_rf['train_r2'].mean())
print("Validation R2 Mean:",
      cv_rf['test_r2'].mean())
print("Validation R2 Std:",
      cv_rf['test_r2'].std())
print("Validation MAE:",
      -cv_rf['test_mae'].mean())
print("Validation RMSE:",
      -cv_rf['test_rmse'].mean())
# Out:
# Train R2 Mean: 0.9524424594061124
# Validation R2 Mean: 0.9034855042676749
# Validation R2 Std: 0.0047206302081746155
# Validation MAE: 0.1673453273805009
# Validation RMSE: 0.2261715609506818

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=10)

# %%
y_pred_rf=rf.predict(x_test)

# %%
y_pred_rf_actual = np.expm1(y_pred_rf)

# %%
print("MAE:",mean_absolute_error(y_test_actual, y_pred_rf_actual))
print("MSE:",mean_squared_error(y_test_actual, y_pred_rf_actual))
print("R2 Score:",r2_score(y_test, y_pred_rf))
# Out:
# MAE: 80516.62494530607
# MSE: 20230199145.82313
# R2 Score: 0.9133163569078616

# %%
residual_rf=y_test_actual-y_pred_rf_actual

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    x=y_pred_rf_actual,
    y=residual,
    alpha=0.6
)

plt.axhline(y=0,
            color='red',
            linestyle='--')

plt.xlabel("Predicted Price")
plt.ylabel("Residuals")
plt.title("Residual Plot - Random Forest")

plt.show()

# %%
# shap vaule chart,feature_importance chart,permutation imp chart

# %% [markdown]
# Residual analysis for Random Forest indicates
# improved error distribution compared to Linear Regression.
#
# Residuals are more tightly concentrated around zero,
# suggesting better predictive performance and improved
# capture of nonlinear relationships.
#
# However, increasing residual variance is still observed
# for high-price vehicles, indicating remaining difficulty
# in modeling luxury car pricing accurately.

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor(max_depth=10,min_samples_split=10,min_samples_leaf=5,random_state=42)
cv_dt=cross_validate(dt,x_train,y_train,cv=5,scoring={
        'r2':'r2',
        'mae':'neg_mean_absolute_error',
        'rmse':'neg_root_mean_squared_error'
    },
    return_train_score=True,
)

print("Train R2 Mean:",
      cv_dt['train_r2'].mean())

print("Validation R2 Mean:",
      cv_dt['test_r2'].mean())

print("Validation R2 Std:",
      cv_dt['test_r2'].std())

print("Validation MAE:",
      -cv_dt['test_mae'].mean())

print("Validation RMSE:",
      -cv_dt['test_rmse'].mean())
# Out:
# Train R2 Mean: 0.9288690713604366
# Validation R2 Mean: 0.8809246694715537
# Validation R2 Std: 0.005570809861604521
# Validation MAE: 0.18525476339031374
# Validation RMSE: 0.2512342077774904

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=10, min_samples_leaf=5, min_samples_split=10,
#                       random_state=42)

# %%
y_pred=dt.predict(x_test)

# %%
y_pred_dt_actual = np.expm1(y_pred)

# %%
print("MSE:",
      mean_squared_error(y_test_actual,
                         y_pred_dt_actual))

print("RMSE:",
      root_mean_squared_error(y_test_actual,
                               y_pred_dt_actual))

print("R2 Score:",
      r2_score(y_test_actual,
               y_pred_dt_actual))
# Out:
# MSE: 26277612274.07101
# RMSE: 162103.7083908663
# R2 Score: 0.9031146730760479

# %%
residual=y_test_actual-y_pred_dt_actual

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    x=y_pred_dt_actual,
    y=residual,
    alpha=0.6
)

plt.axhline(y=0,
            color='red',
            linestyle='--')

plt.xlabel("Predicted Price")
plt.ylabel("Residuals")
plt.title("Residual Plot - decision tree")

plt.show()

# %%
# !pip install xgboost

# %%
from xgboost import XGBRegressor
xg=XGBRegressor(learning_rate=0.02,random_state=42,max_depth=6,n_estimators=200)

# %%
cv_xg=cross_validate(xg,x_train,y_train,cv=5,scoring={
        'r2':'r2',
        'mae':'neg_mean_absolute_error',
        'rmse':'neg_root_mean_squared_error'
    },
    return_train_score=True,
)

print("Train R2 Mean:",
      cv_xg['train_r2'].mean())

print("Validation R2 Mean:",
      cv_xg['test_r2'].mean())

print("Validation R2 Std:",
      cv_xg['test_r2'].std())

print("Validation MAE:",
      -cv_xg['test_mae'].mean())

print("Validation RMSE:",
      -cv_xg['test_rmse'].mean())
# Out:
# Train R2 Mean: 0.9339834244974504
# Validation R2 Mean: 0.9026536840269264
# Validation R2 Std: 0.0049220430217028575
# Validation MAE: 0.16911112057261518
# Validation RMSE: 0.22711817420631922

# %%
xg.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.02, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred=xg.predict(x_test)

# %%
y_pred_xg_actual = np.expm1(y_pred)

# %%
print("MSE:",mean_squared_error(y_test_actual,y_pred_xg_actual))
print("RMSE:",root_mean_squared_error(y_test_actual,y_pred_xg_actual))
print("R2 Score:", r2_score(y_test_actual,y_pred_xg_actual))
# Out:
# MSE: 21849056625.53166
# RMSE: 147814.26394476162
# R2 Score: 0.9194427190695197

# %%
residual=y_test_actual-y_pred_xg_actual

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    x=y_pred_xg_actual,
    y=residual,
    alpha=0.6
)

plt.axhline(y=0,
            color='red',
            linestyle='--')

plt.xlabel("Predicted Price")
plt.ylabel("Residuals")
plt.title("Residual Plot - xgboost")

plt.show()

# %% [markdown]
# ## insight

# %% [markdown]
# Among all the implemented regression models, Random Forest Regressor achieved the best overall performance with the highest R² score of approximately 0.91. The model effectively captured non-linear relationships between vehicle features and selling price while reducing overfitting through ensemble learning. Compared to Linear Regression and Decision Tree Regressor, Random Forest produced more stable and accurate predictions. XGBoost also delivered strong performance with an R² score close to 0.90, indicating excellent predictive capability. However, Random Forest slightly outperformed XGBoost on the current dataset and demonstrated better generalization overall.
#
#
# Despite strong overall performance, both Random Forest and XGBoost struggled to accurately predict high-end luxury vehicles. This limitation is mainly caused by dataset imbalance, where premium vehicles are significantly underrepresented compared to economy and mid-range cars. The absence of luxury-specific features and extreme price variance also contributed to higher prediction errors for premium vehicle segments.

# %%
joblib.dump(sc,'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
joblib.dump(xg,'best_model.pkl')
# Out:
# ['best_model.pkl']

# %%
joblib.dump(
    x.columns.tolist(),
    'model_columns.pkl'
)
# Out:
# ['model_columns.pkl']
